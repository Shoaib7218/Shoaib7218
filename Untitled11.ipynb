# %% [markdown]
# <a href="https://colab.research.google.com/github/Shoaib7218/Shoaib7218/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/2019-Dec.csv')

df = pd.DataFrame(data)

# %%
df.head(100)
# Out:
#                  event_time        event_type  product_id   category_id  \
# 0   2019-12-01 00:00:00 UTC  remove_from_cart   5712790.0  1.487580e+18
# 1   2019-12-01 00:00:00 UTC              view   5764655.0  1.487580e+18
# 2   2019-12-01 00:00:02 UTC              cart      4958.0  1.487580e+18
# 3   2019-12-01 00:00:05 UTC              view   5848413.0  1.487580e+18
# 4   2019-12-01 00:00:07 UTC              view   5824148.0  1.487580e+18
# ..                      ...               ...         ...           ...
# 95  2019-12-01 00:03:53 UTC              view   5765554.0  1.487580e+18
# 96  2019-12-01 00:03:55 UTC  remove_from_cart   5884014.0  1.487580e+18
# 97  2019-12-01 00:03:56 UTC              view   5655060.0  1.487580e+18
# 98  2019-12-01 00:03:56 UTC  remove_from_cart   5884014.0  1.487580e+18
# 99  2019-12-01 00:03:58 UTC  remove_from_cart   5884285.0  1.487580e+18
#
#    category_code      brand  price      user_id  \
# 0            NaN      f.o.x   6.27  576802932.0
# ...

# %%
df.info()
print(df['event_time'].value_counts)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401056 entries, 0 to 401055
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   event_time     401056 non-null  object
#  1   event_type     401055 non-null  object
#  2   product_id     401055 non-null  float64
#  3   category_id    401055 non-null  float64
#  4   category_code  6876 non-null    object
#  5   brand          228244 non-null  object
#  6   price          401055 non-null  float64
#  7   user_id        401055 non-null  float64
#  8   user_session   400958 non-null  object
# dtypes: float64(4), object(5)
# memory usage: 27.5+ MB
# <bound method IndexOpsMixin.value_counts of 0         2019-12-01 00:00:00 UTC
# 1         2019-12-01 00:00:00 UTC
# 2         2019-12-01 00:00:02 UTC
# 3         2019-12-01 00:00:05 UTC
# 4         2019-12-01 00:00:07 UTC
#                    ...
# 401051    2019-12-04 00:52:18 UTC
# ...

# %% [markdown]
# Here We have Just shown How to Replace data as we dont have much mixed datatype but we have replced our data

# %%
df['event_time'].replace('2019-12-04 00:52:18 UTC','2019-12-04 00:52:18')
# Out:
# 0         2019-12-01 00:00:00 UTC
# 1         2019-12-01 00:00:00 UTC
# 2         2019-12-01 00:00:02 UTC
# 3         2019-12-01 00:00:05 UTC
# 4         2019-12-01 00:00:07 UTC
#                    ...
# 401051        2019-12-04 00:52:18
# 401052    2019-12-04 00:52:19 UTC
# 401053    2019-12-04 00:52:19 UTC
# 401054    2019-12-04 00:52:19 UTC
# 401055          2019-12-04 00:52:
# Name: event_time, Length: 401056, dtype: object

# %% [markdown]
# Here we will see how to Change the Datatype

# %%
df['product_id'] = df['product_id'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401056 entries, 0 to 401055
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   event_time     401056 non-null  object
#  1   event_type     401055 non-null  object
#  2   product_id     401056 non-null  object
#  3   category_id    401055 non-null  float64
#  4   category_code  6876 non-null    object
#  5   brand          228244 non-null  object
#  6   price          401055 non-null  float64
#  7   user_id        401055 non-null  float64
#  8   user_session   400958 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 27.5+ MB
